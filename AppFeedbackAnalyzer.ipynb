# %% [markdown]
# # Sentiment Analysis

# %%
import pandas as pd
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import ollama

# %%
# Initialize the sentiment intensity analyzer
analyzer = SentimentIntensityAnalyzer()

# Read the CSV file
df = pd.read_csv('Clash Royale.csv')

# %%
# Apply sentiment analysis to the 'Review Text' column
df['Sentiment'] = df['Review Text'].apply(lambda x: 'Positive' if analyzer.polarity_scores(x)['compound'] > 0 else ('Neutral' if analyzer.polarity_scores(x)['compound'] == 0 else 'Negative'))

# %%
df
# Out:
#         Reviewer Name       Review Date  \
# 0          Josh Coker    March 22, 2024
# 1       Danny Hammett    March 18, 2024
# 2           Harry Sax    March 24, 2024
# 3          Jin’s Jams    March 19, 2024
# 4        Trason Brown    March 24, 2024
# 5      Mathias Gebeau    March 24, 2024
# 6        J Halofan360    March 22, 2024
# 7     Peter Thomasson    March 18, 2024
# 8     John Henry Ryan     March 5, 2024
# 9         Aarush Arun  February 5, 2024
# 10       Averi Ludwig   January 4, 2024
# 11               Tidy     March 1, 2024
# 12      Presley Ashby  January 19, 2024
# 13     Kaison Kilburn   January 4, 2024
# 14  Marshall Kneisley  October 11, 2023
# 15          Huntn 007  November 2, 2023
# 16      Richie Rivera     March 1, 2024
# 17       Ethan Torres    March 18, 2024
# 18        Seth Parker     March 3, 2024
# 19         Red Menace    March 17, 2024
#
#                                           Review Text Sentiment
# 0   It used to be a lot of fun before the last upd...  Positive
# 1   It was a far more simple and enjoyable in 2016...  Positive
# 2   Having to start over, original account keeps c...  Positive
# 3   Menus suck to navigate. It's currently impossi...  Positive
# 4   It is extremely pay to win and just frustratin...  Positive
# 5   Great game! A friend recommended it to me and ...  Positive
# 6   (3/21/2024) Games feels fair. I've been playin...  Positive
# 7   So here's the scenario. You've been playing th...  Negative
# 8   Listen, I love the game. I've been playing it ...  Positive
# 9   Honestly, my initial thoughts to the game were...  Positive
# 10  I loved this game when I first played in 2013 ...  Positive
# 11  It's fun, but pay 2 win now. There's a slight ...  Positive
# 12  Fun but it feels like people have figured out ...  Positive
# 13  This game gets worse with every update. The ne...  Negative
# 14  Used to be a fun game now it's just frustratin...  Negative
# 15  This game has gone to the dumpster. The level ...  Negative
# 16  At this point I think the game is rigged. I've...  Positive
# 17  Used to play this all the time and I enjoyed i...  Positive
# 18  I've been playing since the game came out, and...  Positive
# 19  The game is very good, been playing since laun...  Positive

# %% [markdown]
# # Embeddings

# %%
# Function to get embeddings for a text using Ollama
def get_ollama_embedding(text):
    embedding_dict = ollama.embeddings(model='nomic-embed-text', prompt=text)
    return embedding_dict['embedding']

# Apply Ollama embeddings to the 'Review Text' column
df['Embeddings'] = df['Review Text'].apply(get_ollama_embedding)

# %%
df
# Out:
#         Reviewer Name       Review Date  \
# 0          Josh Coker    March 22, 2024
# 1       Danny Hammett    March 18, 2024
# 2           Harry Sax    March 24, 2024
# 3          Jin’s Jams    March 19, 2024
# 4        Trason Brown    March 24, 2024
# 5      Mathias Gebeau    March 24, 2024
# 6        J Halofan360    March 22, 2024
# 7     Peter Thomasson    March 18, 2024
# 8     John Henry Ryan     March 5, 2024
# 9         Aarush Arun  February 5, 2024
# 10       Averi Ludwig   January 4, 2024
# 11               Tidy     March 1, 2024
# 12      Presley Ashby  January 19, 2024
# 13     Kaison Kilburn   January 4, 2024
# 14  Marshall Kneisley  October 11, 2023
# 15          Huntn 007  November 2, 2023
# 16      Richie Rivera     March 1, 2024
# 17       Ethan Torres    March 18, 2024
# 18        Seth Parker     March 3, 2024
# 19         Red Menace    March 17, 2024
#
#                                           Review Text Sentiment  \
# 0   It used to be a lot of fun before the last upd...  Positive
# 1   It was a far more simple and enjoyable in 2016...  Positive
# 2   Having to start over, original account keeps c...  Positive
# 3   Menus suck to navigate. It's currently impossi...  Positive
# 4   It is extremely pay to win and just frustratin...  Positive
# 5   Great game! A friend recommended it to me and ...  Positive
# 6   (3/21/2024) Games feels fair. I've been playin...  Positive
# 7   So here's the scenario. You've been playing th...  Negative
# 8   Listen, I love the game. I've been playing it ...  Positive
# 9   Honestly, my initial thoughts to the game were...  Positive
# 10  I loved this game when I first played in 2013 ...  Positive
# 11  It's fun, but pay 2 win now. There's a slight ...  Positive
# 12  Fun but it feels like people have figured out ...  Positive
# 13  This game gets worse with every update. The ne...  Negative
# 14  Used to be a fun game now it's just frustratin...  Negative
# 15  This game has gone to the dumpster. The level ...  Negative
# 16  At this point I think the game is rigged. I've...  Positive
# 17  Used to play this all the time and I enjoyed i...  Positive
# 18  I've been playing since the game came out, and...  Positive
# 19  The game is very good, been playing since laun...  Positive
#
#                                            Embeddings
# 0   [1.3746587038040161, 1.0207935571670532, -2.19...
# 1   [-0.23821090161800385, 0.9385673999786377, -2....
# 2   [1.4808236360549927, -0.4910238981246948, -2.1...
# 3   [-0.7348443865776062, 0.7163373231887817, -2.4...
# 4   [-0.13205881416797638, 1.3868826627731323, -2....
# 5   [0.4058516323566437, 0.3468188941478729, -2.31...
# 6   [0.5046795010566711, 1.539804220199585, -2.069...
# 7   [0.7761297821998596, 0.7057363390922546, -2.74...
# 8   [0.08693960309028625, 1.8776923418045044, -2.3...
# 9   [0.7121961116790771, 1.1506856679916382, -2.01...
# 10  [0.5945361256599426, 0.5423089861869812, -2.53...
# 11  [-0.08040495216846466, 1.6395139694213867, -2....
# 12  [0.5806712508201599, 0.9651540517807007, -2.96...
# 13  [0.20107972621917725, 0.2016991525888443, -2.4...
# 14  [0.8280490040779114, 0.8127193450927734, -1.93...
# 15  [0.7778952121734619, 0.8786323666572571, -2.71...
# 16  [-0.05553817376494408, 1.393044114112854, -2.8...
# 17  [-0.49508368968963623, -0.003713995683938265, ...
# 18  [0.5198483467102051, 0.8593501448631287, -2.96...
# 19  [1.1023374795913696, -0.446793794631958, -2.34...

# %% [markdown]
# # Top 20 Dissimilar Reviews

# %%
from sklearn.metrics.pairwise import cosine_similarity

# Assuming 'Embeddings' column holds the pre-computed embeddings
embeddings = df['Embeddings'].tolist()

# Calculate pairwise cosine similarity between all reviews
similarity_matrix = cosine_similarity(embeddings)

# Function to find most dissimilar reviews for a given review index
def find_dissimilar_reviews(review_index, num_reviews=20):
  # Get similarity scores for the chosen review
  similarity_scores = similarity_matrix[review_index]

  # Sort reviews based on similarity (descending order)
  sorted_reviews = sorted(enumerate(similarity_scores), key=lambda x: x[1], reverse=True)

  # Skip the first element (itself) and pick top num_reviews most dissimilar
  return sorted_reviews[1:num_reviews+1]

# Example: Find the top 20 most dissimilar reviews for the first review
dissimilar_reviews = find_dissimilar_reviews(0, num_reviews=len(embeddings))

# Print review text and corresponding similarity score for each dissimilar review
for review_idx, similarity in dissimilar_reviews:
  print(f"Review Index: {review_idx}, Similarity: {similarity:.4f}")
  print(df.loc[review_idx, 'Review Text'])
  print("-"*20)

# You can repeat the find_dissimilar_reviews function for other review indices
# to find their most dissimilar reviews.
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 from sklearn.metrics.pairwise import cosine_similarity
#       3 # Assuming 'Embeddings' column holds the pre-computed embeddings
#       4 embeddings = df['Embeddings'].tolist()
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
dissimilar_reviews
# Out:
# [(9, 0.7266918686432985),
#  (13, 0.6950907641663449),
#  (10, 0.6702221817712706),
#  (15, 0.6572325924299144),
#  (18, 0.6543237230826517),
#  (1, 0.6447301284406438),
#  (14, 0.6196147522294426),
#  (16, 0.5759982065462638),
#  (6, 0.570039506396985),
#  (12, 0.568886584680225),
#  (17, 0.5653069782909359),
#  (4, 0.5590407790964753),
#  (8, 0.5442930419425311),
#  (3, 0.5170329934816917),
#  (11, 0.5164426648807537),
#  (5, 0.5075633158062691),
#  (19, 0.4921260714542186),
#  (2, 0.44691792346340337),
#  (7, 0.43002304290886817)]

# %% [markdown]
# # FR and NFR

# %%
dis_reviews = []
for review_idx, similarity in dissimilar_reviews:
  # print(f"Review Index: {review_idx}, Similarity: {similarity:.4f}")
  dis_reviews.append(df.loc[review_idx, 'Review Text'])

# %%
len(dis_reviews), type(dis_reviews)
# Out:
# (19, list)

# %%
dis_reviews_string = ', '.join(dis_reviews[:5])

# %%
len(dis_reviews_string), type(dis_reviews_string)
# Out:
# (2496, str)

# %%
import ollama

# %%
def prompt_phi3_fr_nfr(prompt, system_prompt="You have to classify functional and non function requirements in points."):
    if len(system_prompt) > 0:
        response = ollama.chat(model="phi3", messages=[
            {'role': 'system', 'content': system_prompt},
            {'role': 'user', 'content': f'Classify Functional and non-functioal requirements: {prompt}'},
        ])
    else:
        response = ollama.chat(model="phi3", messages=[
            {'role': 'user', 'content': f'Classify Functional and non-functional requirements: {prompt}'},
        ])

    return response["message"]["content"]

# %%
prompt = dis_reviews_string

# %%
response = prompt_phi3_fr_nfr(prompt)
print(response)
# Out:
# Functional Requirements:
# 1. A user-friendly interface that allows players to create decks efficiently without navigating between multiple tabs or sections.
# 2. Stable and reliable gameplay connection, ensuring minimal disconnections during mid-game play.
# 3. Balanced in-game economy where skill development and strategic thinking are rewarded over pay-to-win mechanics.
# 4. Incremental trophy acquisition that continues to provide satisfaction even after reaching significant milestones (e.g., 4000 trophies).
# 5. Regular updates with improvements in gameplay balance, avoiding drastic shifts towards a pay-to-win model.
# 6. A fair leveling system where players can progress through different levels based on skill and strategy rather than financial investment.
# 7. Consistent value for new card releases that maintain the competitive integrity of the game by not overpowering existing strategies.
# 8. Preservation of core gameplay features that fans appreciated, such as original mechanics and nostalgic elements like the first-release experience.
#
# Non-Functional Requirements:
# 1. Improved customer support to address player concerns regarding in-game purchases, disconnections, and UI issues promptly.
# 2. Community engagement strategies that involve players' feedback into the game development process.
# 3. Regular communication with the gaming community about changes being made to the game's economy or mechanics to maintain transparency.
# 4. Implementation of anti-cheat measures to ensure fair play among all users, irrespective of their investment in the game.
# 5. A system for acknowledging and rewarding long-time players who have contributed significantly to the community since its release.

# %% [markdown]
# # Suggestion

# %%
def prompt_phi3_suggestion(prompt, system_prompt='''Given a set of customer reviews for a product or service, provide suggestions on how to improve based on recurring issues or complaints mentioned in the reviews. Consider aspects such as product features, user experience, customer service, pricing, or any other relevant factors. Your suggestions should aim to address the identified problems and enhance overall satisfaction for customers.'''):
    if len(system_prompt) > 0:
        response = ollama.chat(model="phi3", messages=[
            {'role': 'system', 'content': system_prompt},
            {'role': 'user', 'content': f'Give me Suggestions in points: {prompt}'},
        ])
    else:
        response = ollama.chat(model="phi3", messages=[
            {'role': 'user', 'content': f'Give me Suggestions in points: {prompt}'},
        ])

    return response["message"]["content"]

# %%
response = prompt_phi3_suggestion(prompt)
print(response)
# Out:
# Based on the recurring issues mentioned in customer reviews for Clash Royale, here are some suggestions to improve the game and enhance overall satisfaction:
#
# 1. Balanced reward system: Ensure that players can progress through levels based solely on their skill and dedication, rather than monetary investment. This will help maintain a fair playing environment where everyone has an equal chance of winning.
#
# 2. Fair pricing structure: Evaluate the current in-game purchases (loot boxes, premium cards) to ensure that they do not disproportionately affect gameplay and enjoyment for those who don't want to spend money. Consider implementing a fairer monetization strategy with transparent value propositions.
#
# 3. Address overpowered elements: Investigate the complaints about new additions or updates making certain cards too powerful, creating an unbalanced meta that discourages non-paying players from enjoying the game competitively. Balance these features to ensure fair play for everyone.
#
# 4. Improve connectivity stability: Prioritize addressing issues related to poor connection and disconnections during games, as this significantly impacts player experience and satisfaction. Ensure that technical support is readily available in case of such problems.
#
# 5. Revamp the user interface (UI): Simplify navigation within the game's UI by reducing tab switching and making essential elements more prominent to streamline gameplay experience and assist players in finding required items quickly.
#
# 6. Revisit leveling mechanics: Make sure that the level system encourages skill development rather than a pay-to-level strategy, allowing every player to enjoy the progression process without feeling pressured to spend money.
#
# 7. Engage with loyal customers and address their concerns: Continue engaging with your core community of players by gathering feedback on proposed changes and implementing improvements that resonate well with them. This will foster a sense of ownership among existing fans, improving overall satisfaction for both long-time players and new ones.
#
# By addressing these recurring issues and focusing on creating an enjoyable and fair experience for all players, Clash Royale can regain its former reputation as a competitive and fun game that encourages skill development over monetary investment.
